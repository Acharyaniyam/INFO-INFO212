# %% [markdown]
# # INFO 212: Data Science Programming 1
# ## CCI at Drexel University
#
#
# ## Lab: Visualization

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## What to do:
# - Answer each question individually.
# - Comment on each single statement.
# - Each missing comment will be penalized by 1 point.
# - Verify the code by showing meaningful results.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Exercise
# The Iris flower data set consists of 50 samples from each of three species of Iris Flowers — Iris Setosa, Iris Virginica and Iris Versicolor:
#
# ![](https://i.imgur.com/jb6jvPy.png)
#
# Each flower is described by 4 features: sepal length, sepal width, petal length and petal width, in centimeters.

# %% [markdown]
# 1. Load the iris.csv data into a DataFrame. Show the shape of the dataset. List the columns and their datatypes. Compute summary statistics. Show the first 5 rows of the data.

# %%
data = pd.read_csv('/content/drive/MyDrive/info212/iris.csv')
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data['sepal_length'].value_counts() #Counts the frequency of unique values
# Out:
# sepal_length
# 5.0    10
# 5.1     9
# 6.3     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 5.4     6
# 6.1     6
# 6.0     6
# 5.6     6
# 4.8     5
# 6.5     5
# 6.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 5.9     3
# 4.4     3
# 7.2     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 7.3     1
# 7.0     1
# 7.1     1
# 5.3     1
# 4.3     1
# 4.5     1
# 7.9     1
# Name: count, dtype: int64

# %% [markdown]
# [link text](https://)2. List the unique names of the species. Show the distribution of species.

# %%
#get the unique values of species column
unique_species = data['species'].unique()
print("Unique species names:", unique_species)

#get the distribution of species
species_distribution = data['species'].value_counts()
print("\nDistribution of species:\n", species_distribution)
# Out:
# Unique species names: ['setosa' 'versicolor' 'virginica']
#
# Distribution of species:
#  species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# 3.  Use seaborn.histplot() to plot histograms for each of the feature columns, colored by the species. You should have 4 histogram plots. What do you see from the plots? Explain the distributions against the species.

# %%
# Iterate through the feature columns and create histograms for each
for feature in ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']:
  plt.figure(figsize=(10, 6))
  sns.histplot(data=data, x=feature, hue='species', kde=True)  # kde=True adds kernel density estimate
  plt.title(f'Distribution of {feature} by Species')
  plt.xlabel(feature)
  plt.ylabel('Frequency')
  plt.show()

#Sepal Length: The distributions of sepal length for Iris-setosa are generally shorter compared to Iris-versicolor and Iris-virginica. Iris-versicolor and Iris-virginica have overlapping distributions, making it difficult to distinguish them based on sepal length alone.

#Sepal Width: Iris-setosa has a narrower sepal width distribution compared to the other two species. Iris-versicolor and Iris-virginica exhibit some overlap in their sepal width distributions.

#Petal Length: Petal length provides the most significant separation between species. Iris-setosa has much shorter petals compared to the other two species. Iris-versicolor and Iris-virginica have some overlap in their petal length distributions, but Iris-virginica tends to have slightly longer petals.

#Petal Width: Similar to petal length, petal width also offers a strong distinction between species. Iris-setosa has very narrow petals, while Iris-versicolor and Iris-virginica show a clear difference in petal width, with Iris-virginica having wider petals on average.

# %% [markdown]
# 4. Scatter plot all pairs of different features and color the points with the species. You should have 6 scatter plots.

# %%
# Create a list of feature pairs
feature_pairs = [
    ('sepal_length', 'sepal_width'),
    ('sepal_length', 'petal_length'),
    ('sepal_length', 'petal_width'),
    ('sepal_width', 'petal_length'),
    ('sepal_width', 'petal_width'),
    ('petal_length', 'petal_width')
]

# Loop through the feature pairs and create a scatter plot for each
for x_feature, y_feature in feature_pairs:
  plt.figure(figsize=(10, 4))  # Adjust figure size as needed
  sns.scatterplot(data=data, x=x_feature, y=y_feature, hue='species')
  plt.title(f'{x_feature} vs {y_feature}')
  plt.xlabel(x_feature)
  plt.ylabel(y_feature)
  plt.show()

# %% [markdown]
# 5. Based on the plots in above question (4), write a brief discussion of your findings about the features and species. For example, which features are indicative to separate the species, etc.

# %%
#Petal length and petal width are the most effective features for separating the Iris species.
#    - Iris-setosa is clearly distinct from the other two species based on its shorter petal length and width.
#    - Iris-versicolor and Iris-virginica show some overlap but can generally be differentiated by their petal length and width.

#Sepal length and sepal width are less effective in separating the species, especially between Iris-versicolor and Iris-virginica.
#    - There is some overlap between these species in terms of sepal length and width, making it difficult to reliably classify them using only these features.

#Combining features provides better classification.
#    - For example, using petal length and petal width together allows for a clearer distinction between all three species compared to using only one of these features.

# They provide the most clear distinction between Iris-setosa and the other two species, and also help in differentiating between Iris-versicolor and Iris-virginica.
